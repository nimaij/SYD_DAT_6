# %% [markdown]
# # Data Science Course Week 2 - Data Visuaisation
#
# ## We will be exploring datasets with Python visualisation libraries
#
# For more information refer to the [Pandas Documentation](http://pandas.pydata.org/pandas-docs/stable/visualization.html) and the [Plotly Documentation](https://plot.ly/python/offline/)

# %% [markdown]
# ### 1. Matplotlib
# The easiest way to visualise Pandas Dataframes

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot') # This styles the graphs in a nicer format

# %%
# read drinks.csv into a DataFrame called 'drinks'
drinks = pd.read_table('drinks.csv', sep=',')
drinks = pd.read_csv('drinks.csv')              # assumes separator is comma

# %%
# bar plot of number of countries in each continent
drinks.continent.value_counts().plot(kind='bar', title='Countries per Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
#plt.show()                                  # show plot window (if it doesn't automatically appear)
plt.savefig('countries_per_continent.png')  # save plot to file

# %%
# bar plot of average number of beer servings (per adult per year) by continent
drinks.groupby('continent').beer_servings.mean().plot(kind='bar', title='Beer servings per year, per Continent')
plt.ylabel('Average Number of Beer Servings Per Year')

# %%
# bar plot of average number of wine servings (per adult per year) by continent
drinks.groupby('continent').wine_servings.mean().plot(kind='bar', title='Wine servings per year, per Continent')
plt.ylabel('Average Number of Wine Servings Per Year')

# %%
# histogram of beer servings (shows the distribution of a numeric column)
drinks.beer_servings.hist(bins=15)
plt.xlabel('Beer Servings')
plt.ylabel('Frequency')

# %%
# density plot of beer servings (smooth version of a histogram)
drinks.beer_servings.plot(kind='density', xlim=(0,500))
plt.xlabel('Beer Servings')

# %%
# grouped histogram of beer servings (shows the distribution for each group)
drinks.beer_servings.hist(by=drinks.continent, sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1186a6810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1187e6dd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1188a5a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a31310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118aa8f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b2ca10>]], dtype=object)

# %%
# boxplot of beer servings by continent (shows five-number summary and outliers)
drinks.boxplot(column='beer_servings', by='continent')

# %%
# scatterplot of beer servings versus wine servings
drinks.plot(kind='scatter', x='beer_servings', y='wine_servings', alpha=0.3)

# %%
# same scatterplot, except point color varies by 'spirit_servings'
drinks.plot(kind='scatter', x='beer_servings', y='wine_servings', c='spirit_servings', colormap='Blues')

# %%
# same scatterplot, except point color varies by 'spirit_servings'
drinks.plot(kind='scatter', x='beer_servings', y='spirit_servings', c='wine_servings', colormap='Blues')

# %%
# same scatterplot, except all European countries are colored red
colors = np.where(drinks.continent=='EU', 'r', 'b')
drinks.plot(kind='scatter', x='beer_servings', y='wine_servings', c=colors)

# %%
# scatterplot matrix of all numerical columns
pd.scatter_matrix(drinks, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11aab4390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ad14810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11adce890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ae31f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11aeb2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ae55950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11afaf290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b961210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b9c4910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb46890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bba99d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc2aa50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bc39e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be1bad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bea0a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bf02c90>]], dtype=object)

# %% [markdown]
# ### 2. ggplot
# This is a mimic of an R package for plotting that is very popular. The benefit of learning this package is that you will be able to think the same way about plotting in both Python and R.
# https://github.com/yhat/ggplot
#
# Rough syntax:
#
# - For common plots, establish the data source and data mapping with ggplot and aes:
#     - ggplot(data, aes(x='var', y='var2'))
#
# - Then add geometries (plot objects) that depend on the data mappings:
#     - geom_histogram()
#     - geom_point()
#
# A good recent post about ploting libraries avaiable in Python and how their syntax differ: https://dansaber.wordpress.com/2016/10/02/a-dramatic-tour-through-pythons-data-visualization-landscape-including-ggplot-and-altair/
#
# The 'R Graphics Cookbook' by Winston Chang is a great book on how to achieve what you want with ggplot()

# %%
# !pip install -U ggplot
#!conda install -c conda-forge ggplot
# Out:
# Collecting ggplot
#   Downloading ggplot-0.11.5-py2.py3-none-any.whl (2.2MB)
#     100% |████████████████████████████████| 2.2MB 40kB/s
# Collecting brewer2mpl (from ggplot)
#   Downloading brewer2mpl-1.4.1-py2.py3-none-any.whl
# Collecting scipy (from ggplot)
#   Downloading scipy-0.18.1-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (21.8MB)
#     100% |████████████████████████████████| 21.8MB 6.2kB/s
# Requirement already up-to-date: statsmodels in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from ggplot)
# Requirement already up-to-date: patsy>=0.4 in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from ggplot)
# Requirement already up-to-date: cycler in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from ggplot)
# Requirement already up-to-date: six in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from ggplot)
# Collecting numpy (from ggplot)
#   Downloading numpy-1.11.2-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.9MB)
#     100% |████████████████████████████████| 3.9MB 115kB/s
# Collecting pandas (from ggplot)
#   Downloading pandas-0.19.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (11.3MB)
#     100% |████████████████████████████████| 11.3MB 42kB/s
# Collecting matplotlib (from ggplot)
#   Downloading matplotlib-1.5.3-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (11.2MB)
#     100% |████████████████████████████████| 11.2MB 44kB/s
# Requirement already up-to-date: pytz>=2011k in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from pandas->ggplot)
# Requirement already up-to-date: python-dateutil in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from pandas->ggplot)
# Collecting pyparsing!=2.0.0,!=2.0.4,!=2.1.2,>=1.5.6 (from matplotlib->ggplot)
#   Downloading pyparsing-2.1.10-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 3.9MB/s
# Installing collected packages: brewer2mpl, numpy, scipy, pandas, pyparsing, matplotlib, ggplot
#   Found existing installation: numpy 1.11.1
#     Uninstalling numpy-1.11.1:
#       Successfully uninstalled numpy-1.11.1
#   Found existing installation: scipy 0.17.1
#     DEPRECATION: Uninstalling a distutils installed project (scipy) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling scipy-0.17.1:
#       Successfully uninstalled scipy-0.17.1
#   Found existing installation: pandas 0.18.1
#     Uninstalling pandas-0.18.1:
#       Successfully uninstalled pandas-0.18.1
#   Found existing installation: pyparsing 2.1.4
#     Uninstalling pyparsing-2.1.4:
#       Successfully uninstalled pyparsing-2.1.4
#   Found existing installation: matplotlib 1.5.1
#     Uninstalling matplotlib-1.5.1:
#       Successfully uninstalled matplotlib-1.5.1
# Successfully installed brewer2mpl-1.4.1 ggplot-0.11.5 matplotlib-1.5.3 numpy-1.11.2 pandas-0.19.0 pyparsing-2.1.10 scipy-0.18.1

# %%
from ggplot import *

# %% [markdown]
# #### A Single Variable: Shape and Distribution

# %%
# data set mpg - included in ggplot package - car fuel mileage
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# Single variable analysis: histogram
ggplot(mpg, aes(x='cty')) + geom_histogram()
# Out:
# <ggplot: (300077713)>

# %% [markdown]
# ##### Kernel Density Estimates
# To form a KDE, we place a kernel—that is, a smooth, strongly peaked function—at the position of each data point. We then add up the contributions from all kernels to obtain a smooth curve, which we can evaluate at any point along the x axis.
#
# Example Kernels:
# (Gaussian must commonly used)
#
# ![KDE](KDE_kernals.png)

# %%
# Single variable analysis: kernel density estimate
ggplot(mpg, aes(x='cty')) + geom_density()

# %%
# Single variable analysis: kernel density estimate with plots split by drivetrain variable
ggplot(mpg, aes(x='cty', colour='drv')) + geom_density()

# %%
# Single variable analysis: kernel density estimate with plots split by drivetrain variable, faceted
ggplot(mpg, aes(x='cty', colour='drv')) + geom_density() + facet_grid('drv')

# %% [markdown]
# ##### Box plot and Violin plot

# %%
# Single variable analysis: Box Plot
ggplot(mpg, aes(x='cyl', y='cty')) + geom_boxplot()

# %%
# Single variable analysis: Violin Plot - applies the kernel density transformation per category
ggplot(mpg, aes(x='cyl', y='cty')) + geom_violin()

# %% [markdown]
# #### Two Variables: establishing a relationship

# %%
# data set diamonds - included in ggplot package
diamonds.head()

# %%
# scatter plot
# backslash indicates the statement continues on the next line. Make sure no characters follow the slash on that line. 
ggplot(diamonds, aes('carat','price', colour='cut')) + \
    geom_point(alpha=0.7) + \
    ggtitle('Diamond Price vs Carat')

# %% [markdown]
# ### 3. Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
# !pip install plotly --upgrade

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print __version__ # requires version >= 1.9.0

# %%
init_notebook_mode() # run at the start of every ipython notebook to use plotly.offline
                     # this injects the plotly.js source files into the notebook

# %%
from plotly.graph_objs import *
import numpy as np

# %%
# Scatter plot with heatmap
x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)

# %%
df_airports = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df_airports.head()

df_flight_paths = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_aa_flight_paths.csv')
df_flight_paths.head()

airports = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_airports['long'],
        lat = df_airports['lat'],
        hoverinfo = 'text',
        text = df_airports['airport'],
        mode = 'markers',
        marker = dict(
            size=2,
            color='rgb(255, 0, 0)',
            line = dict(
                width=3,
                color='rgba(68, 68, 68, 0)'
            )
        ))]

flight_paths = []
for i in range( len( df_flight_paths ) ):
    flight_paths.append(
        dict(
            type = 'scattergeo',
            locationmode = 'USA-states',
            lon = [ df_flight_paths['start_lon'][i], df_flight_paths['end_lon'][i] ],
            lat = [ df_flight_paths['start_lat'][i], df_flight_paths['end_lat'][i] ],
            mode = 'lines',
            line = dict(
                width = 1,
                color = 'red',
            ),
            opacity = float(df_flight_paths['cnt'][i])/float(df_flight_paths['cnt'].max()),
        )
    )

layout = dict(
        title = 'Feb. 2011 American Airline flight paths<br>(Hover for airport names)',
        showlegend = False,
        height = 800,
        geo = dict(
            scope='north america',
            projection=dict( type='azimuthal equal area' ),
            showland = True,
            landcolor = 'rgb(243, 243, 243)',
            countrycolor = 'rgb(204, 204, 204)',
        ),
    )

fig = dict( data=flight_paths + airports, layout=layout )

iplot(fig)
